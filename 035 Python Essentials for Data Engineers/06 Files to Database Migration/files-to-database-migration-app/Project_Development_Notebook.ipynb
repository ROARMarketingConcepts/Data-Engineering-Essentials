# %%
# Required for Notebook to use SQL Magic
# Facilitates to run queries from Notebooks 
# without using Python Code
# !pip install ipython-sql

# %%
# Native Postgres Library to connect to Posgres Database Server
# !pip install psycopg2-binary

# %%
# SQLAlchemy is ORM and needs native database libraries (psycopg2)
# Pandas internally uses SQL Alchemy to connect to database
# !pip install sqlalchemy==1.4.22

# %%
load_ext sql

# %%
# %env DATABASE_URL=postgresql://itversity_retail_user:itversity@localhost:5432/itversity_retail_db
# Out:
# env: DATABASE_URL=postgresql://itversity_retail_user:itversity@localhost:5432/itversity_retail_db

# %%
# %%sql
#
# SELECT * FROM orders LIMIT 10
# Out:
# Traceback (most recent call last):
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sqlalchemy/engine/base.py", line 3212, in _wrap_pool_connect
#     return fn()
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sqlalchemy/pool/base.py", line 307, in connect
#     return _ConnectionFairy._checkout(self)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sqlalchemy/pool/base.py", line 767, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sqlalchemy/pool/base.py", line 425, in checkout
#     rec = pool._do_get()
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sqlalchemy/pool/impl.py", line 145, in _do_get
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sqlalchemy/util/langhelpers.py", line 70, in __exit__
#     compat.raise_(
#     ~~~~~~~~~~~~~^
#         exc_value,
#         ^^^^^^^^^^
#         with_traceback=exc_tb,
#         ^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sqlalchemy/util/compat.py", line 207, in raise_
#     raise exception
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sqlalchemy/pool/impl.py", line 143, in _do_get
#     return self._create_connection()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sqlalchemy/pool/base.py", line 253, in _create_connection
#     return _ConnectionRecord(self)
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sqlalchemy/pool/base.py", line 368, in __init__
#     self.__connect()
#     ~~~~~~~~~~~~~~^^
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sqlalchemy/pool/base.py", line 610, in __connect
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sqlalchemy/util/langhelpers.py", line 70, in __exit__
#     compat.raise_(
#     ~~~~~~~~~~~~~^
#         exc_value,
#         ^^^^^^^^^^
#         with_traceback=exc_tb,
#         ^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sqlalchemy/util/compat.py", line 207, in raise_
#     raise exception
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sqlalchemy/pool/base.py", line 605, in __connect
#     connection = pool._invoke_creator(self)
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sqlalchemy/engine/create.py", line 578, in connect
#     return dialect.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sqlalchemy/engine/default.py", line 584, in connect
#     return self.dbapi.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/psycopg2/__init__.py", line 122, in connect
#     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
# psycopg2.OperationalError: connection to server at "localhost" (127.0.0.1), port 5432 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
# connection to server at "localhost" (::1), port 5432 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
#
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sql/magic.py", line 196, in execute
#     conn = sql.connection.Connection.set(
#         connect_str,
#     ...<2 lines>...
#         creator=args.creator,
#     )
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sql/connection.py", line 78, in set
#     cls.current = Connection(
#                   ~~~~~~~~~~^
#         os.getenv("DATABASE_URL"), connect_args, creator
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sql/connection.py", line 55, in __init__
#     self.internal_connection = engine.connect()
#                                ~~~~~~~~~~~~~~^^
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sqlalchemy/engine/base.py", line 3166, in connect
#     return self._connection_cls(self, close_with_result=close_with_result)
#            ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sqlalchemy/engine/base.py", line 96, in __init__
#     else engine.raw_connection()
#          ~~~~~~~~~~~~~~~~~~~~~^^
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sqlalchemy/engine/base.py", line 3245, in raw_connection
#     return self._wrap_pool_connect(self.pool.connect, _connection)
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sqlalchemy/engine/base.py", line 3215, in _wrap_pool_connect
#     Connection._handle_dbapi_exception_noconnection(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         e, dialect, self
#         ^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sqlalchemy/engine/base.py", line 2069, in _handle_dbapi_exception_noconnection
#     util.raise_(
#     ~~~~~~~~~~~^
#         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sqlalchemy/util/compat.py", line 207, in raise_
#     raise exception
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sqlalchemy/engine/base.py", line 3212, in _wrap_pool_connect
#     return fn()
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sqlalchemy/pool/base.py", line 307, in connect
#     return _ConnectionFairy._checkout(self)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sqlalchemy/pool/base.py", line 767, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sqlalchemy/pool/base.py", line 425, in checkout
#     rec = pool._do_get()
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sqlalchemy/pool/impl.py", line 145, in _do_get
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sqlalchemy/util/langhelpers.py", line 70, in __exit__
#     compat.raise_(
#     ~~~~~~~~~~~~~^
#         exc_value,
#         ^^^^^^^^^^
#         with_traceback=exc_tb,
#         ^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sqlalchemy/util/compat.py", line 207, in raise_
#     raise exception
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sqlalchemy/pool/impl.py", line 143, in _do_get
#     return self._create_connection()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sqlalchemy/pool/base.py", line 253, in _create_connection
#     return _ConnectionRecord(self)
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sqlalchemy/pool/base.py", line 368, in __init__
#     self.__connect()
#     ~~~~~~~~~~~~~~^^
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sqlalchemy/pool/base.py", line 610, in __connect
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sqlalchemy/util/langhelpers.py", line 70, in __exit__
#     compat.raise_(
#     ~~~~~~~~~~~~~^
#         exc_value,
#         ^^^^^^^^^^
#         with_traceback=exc_tb,
#         ^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sqlalchemy/util/compat.py", line 207, in raise_
#     raise exception
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sqlalchemy/pool/base.py", line 605, in __connect
#     connection = pool._invoke_creator(self)
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sqlalchemy/engine/create.py", line 578, in connect
#     return dialect.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/sqlalchemy/engine/default.py", line 584, in connect
#     return self.dbapi.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "/Users/woodzsan/Desktop/Machine Learning and Data Analysis/Data-Engineering-Essentials/035 Python Essentials for Data Engineers/06 Files to Database Migration/files-to-database-migration-app/ftd_migration/lib/python3.13/site-packages/psycopg2/__init__.py", line 122, in connect
#     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
# sqlalchemy.exc.OperationalError: (psycopg2.OperationalError) connection to server at "localhost" (127.0.0.1), port 5432 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
# connection to server at "localhost" (::1), port 5432 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
#
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])
